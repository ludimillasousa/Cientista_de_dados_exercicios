# %% [markdown]
# Exercício 1 - (a)

# %%
prod_higpessoal = 'sabonete'

# %%
est_prodlimpeza = 'sabonete líquido'

# %%
type(prod_higpessoal)
# Out:
# str

# %%
type(est_prodlimpeza)
# Out:
# str

# %%
prod_higpessoal == est_prodlimpeza
# Out:
# False

# %% [markdown]
# Exercício 2 - (b)

# %%
quant_totalalunos = 1048

# %%
capac_salas = 40

# %%
quant_totalalunos % capac_salas
# Out:
# 8

# %%
type(quant_totalalunos)
# Out:
# int

# %%
type(capac_salas)
# Out:
# int
